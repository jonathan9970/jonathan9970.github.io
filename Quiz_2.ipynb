# %% [markdown]
# <a href="https://colab.research.google.com/github/jonathan9970/jonathan9970.github.io/blob/main/Quiz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_leap_year(year):

    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        return True
    else:
        return False
is_leap_year (1000)
# Out:
# False
